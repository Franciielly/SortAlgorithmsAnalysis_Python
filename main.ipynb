# %% [markdown]
# ## Implementação dos Algoritmos

# %% [markdown]
# ## Complexidade Assintótica

# %% [markdown]
# ## Consumo de Memória

# %% [markdown]
# ## Análise Amortizada

# %% [markdown]
# ## Testes e Medição de Desempenho

# %% [markdown]
# ## Conclusão
